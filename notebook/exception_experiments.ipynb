# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import traceback
import sys

# %%
from logger.custom_logger import custom_logger

# %%
custom_logger.get_logger('exception_experiments')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 custom_logger.get_logger('exception_experiments')
#
# TypeError: custom_logger.get_logger() missing 1 required positional argument: 'name'

# %%
from logger.custom_logger import custom_logger

logger = custom_logger().get_logger("exception_experiments.ipynb")

# %%
from logger.custom_logger import custom_logger

logger = custom_logger().get_logger("exception_experiments.ipynb")
logger.info("Logger is working")

# %%
class DocumentPortalException(Exception):
    """Base exception class for Document Portal errors."""

    def __init__(self, error_message, error_details=sys):
        # Capture traceback info
        exc_type, exc_val, exc_tb = error_details.exc_info()

        # Fix: frame attribute is f_code (not fcode)
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.line_number = exc_tb.tb_lineno

        self.error_message = str(error_message)

        # Store full traceback string
        self.traceback_str = "".join(traceback.format_exception(exc_type, exc_val, exc_tb))

        # Initialize base Exception properly
        super().__init__(self.error_message)

    def __str__(self):
        return f"""
Error Message: {self.error_message}
File Name: {self.file_name}
Line Number: {self.line_number}
Traceback: {self.traceback_str}
"""


if __name__ == "__main__":
    try:
        # Simulate an error
        a = 1 / 0
    except Exception as e:
        app_exc = DocumentPortalException(e, sys)
        logger.error(app_exc)
        raise app_exc from e
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 32
#      30 try:
#      31     # Simulate an error
# ---> 32     a = 1 / 0
#      33 except Exception as e:
#
# ZeroDivisionError: division by zero
#
# The above exception was the direct cause of the following exception:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[7], line 36
#      34 app_exc = DocumentPortalException(e, sys)
#      35 logger.error(app_exc)
# ---> 36 raise app_exc from e
#
# DocumentPortalException:
# Error Message: division by zero
# File Name: C:\Users\Karan\AppData\Local\Temp\ipykernel_20232\3542036079.py
# Line Number: 32
# Traceback: Traceback (most recent call last):
#   File "C:\Users\Karan\AppData\Local\Temp\ipykernel_20232\3542036079.py", line 32, in <module>
#     a = 1 / 0
# ZeroDivisionError: division by zero
